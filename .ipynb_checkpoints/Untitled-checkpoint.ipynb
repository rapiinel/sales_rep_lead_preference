# %% [markdown]
# #### Source Files
# 1. Salesforce SaleRep Lead pref - Oppty
#     - https://d300000001vgeeau.my.salesforce.com/00O4y000003xWkb
# 1. Salesforce SaleRep Lead pref - Deal
#     - https://d300000001vgeeau.my.salesforce.com/00O4y000003xWkq

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
tqdm.pandas()

import seaborn as sns

# %% [markdown]
# #### Business Question
# 1. What are the top practice area getting deals?
#     1. Who are the sales rep getting this deals?
#     1. What are their position level?
# 1. What are the type of leads getting deals?

# %%
class dataframe_deals:
    def __init__(self, link):
        self.df = pd.read_csv(link, encoding = 'latin-1')
        self.df.dropna(subset = ['Deal: Deal Name'], inplace = True)
        self.df['Order Date'] = pd.to_datetime(self.df['Order Date'])
        self.practice_area_count()
    
    def practice_area_count(self):
        list = [x for x in self.df.columns if 'Area of Practice' in x]
        self.df['Count of Practice Area'] = self.df.apply(lambda x: 5 - x[list].isna().sum(), axis = 1)
    
    def PA_table(self):
        list = [x for x in self.df.columns if 'Area of Practice' in x]
        list.extend(['Deal: ID', 'Order Date'])
        return self.df[list].melt(id_vars = ['Deal: ID', 'Order Date']).dropna(subset = ['value'])

# %%
deals = dataframe_deals('raw/salesforce salesrep lead pref - deal.csv')

# %% [markdown]
# #### Deals per Practice Area

# %%
test = deals.PA_table()

# %%
df = test.pivot_table(index = ['value'], values = 'variable', aggfunc = 'count').sort_values(by ='variable', ascending = False)

colors = sns.color_palette('pastel')
colors = [colors[0] if df.loc[df.index[x], 'variable'] !=  df.variable.max() else colors[4] for x in range(len(df.index))]
plt.figure(figsize = (15,10))
ax = sns.barplot(data = df, y = df.index, x = 'variable', palette = colors)
for bar in ax.patches:
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    ax.annotate(format(bar.get_width(), ','),
                   (bar.get_width() + 5,
                    bar.get_y() + bar.get_height()), ha='center', va='center',
                   size=10, xytext=(-8, 8),
                   textcoords='offset points')
_ = plt.title("Deals per Practice Area")

# %%
class dataframe_oppty:
    def __init__(self, link):
        self.df = pd.read_csv(link)
        
    def auto_run(self):    
        self.data_preparation()
        self.lead_source_filter()
    
    def datetime(self, list):
        for x in list:
            self.df[x] = pd.to_datetime(self.df[x])
    
    def measureit(method):
        '''using a decorator to measure the before and after of dataframe length'''
        def measured(self):
            initial_len = len(self.df)
            result = method(self)
            final_len = len(self.df)
            
            # Printing the result
            print(method.__name__)            
            print(f"Before using the filter: {initial_len}")
            print(f"After using the filter: {final_len}")
            print(f"The dataframe decreased by: {initial_len - final_len}")
            print('======================')
            return result
        return measured            

    @measureit
    def lead_source_filter(self):
        """Removing all types of renewal from the dataset"""
        remove_values = [x for x in self.df['Lead Source'].unique() if 'renewal' in str(x).lower()]
        self.df = self.df[~self.df['Lead Source'].isin(remove_values)]
        
    @measureit
    def data_preparation(self):
        self.df.dropna(subset = ['Process Tracking For'], inplace = True)
        self.datetime(['Created Date', 'Case Review Set', 'Case Review Completed', 'Enrollment Meeting Set'])
        
        
    def checker(method):
        def nan_checker(*arg, **kwargs):
            if str(arg) != 'nan':
                return method
            else:
                print('nan type')
                return np.nan
        return nan_checker
    
    @checker
    def breaking_practice_areas(self):
        def splitter(string_to_list):
            if str(string_to_list) != 'nan':
                return str(string_to_list).split(';')
            else:
                return np.nan
        
        self.df['Practice Areas - list'] = self.df.apply(lambda x: splitter(x['Practice Areas']), axis = 1)
        self.df['Practice Areas - Length'] = self.df.apply(lambda x: len(x['Practice Areas - list']), axis = 1)
        
        print(f"=========================")
        print(self.df['Practice Areas - Length'].values_count())

# %%
oppty = dataframe_oppty('raw/salesforce salesrep lead pref - oppty.csv')
oppty.auto_run()
# Out:
# data_preparation
# Before using the filter: 8948
# After using the filter: 8943
# The dataframe decreased by: 5
# ======================
# lead_source_filter
# Before using the filter: 8943
# After using the filter: 8722
# The dataframe decreased by: 221
# ======================

# %%
oppty.breaking_practice_areas()
# Out:
# <function __main__.dataframe_oppty.breaking_practice_areas(self)>

# %%
oppty.df
# Out:
#                                        Opportunity Name Process Tracking For  \
# 1     Michel Rene Huff Bus Lit and PI San Diego Upgr...      Russell Winkler
# 4            Timothy Pollard - Immigration Wait LIst LA       Julie Reynolds
# 5         Rob Laher Early Renewal and Upgrade Crim 2022      Russell Winkler
# 6                           Willis Everett Smith 1.3.22     Jennifer Depazza
# 7     Agnieszka Haupt Immigration Early Renewal and ...      Russell Winkler
# ...                                                 ...                  ...
# 8938     Hayley Wilson - Corp Email Engagement - 3.9.22        Erik Martinez
# 8939       Ryan Malone - Corp Email Engagement - 3.9.22        James Susuico
# 8940      Brennan Moss - Corp Email Engagement - 3.9.22         Jeynifer Kaz
# 8941        Brooke Ray - Corp Email Engagement - 3.9.22      Justin Schwartz
# 8942    Stephen Barnes - Corp Email Engagement - 3.9.22        Brandy Sutton
#
#      CR Set Position CR Completed Position     EM Set Position  \
# 1                NaN                   NaN                 NaN
# 4                NaN                   NaN                 NaN
# 5                NaN                   NaN                 NaN
# 6          BDR-AMRM1    Associate Director  Associate Director
# 7                NaN                   NaN                 NaN
# ...              ...                   ...                 ...
# 8938             NaN                   NaN                 NaN
# 8939             NaN                   NaN                 NaN
# 8940             NaN                   NaN                 NaN
# 8941             NaN                   NaN                 NaN
# 8942             NaN                   NaN                 NaN
#
#           Lead Source      Lead Source Type Created Date Case Review Set  \
# 1             UPGRADE                   NaN   2022-02-07      2022-02-07
# 4            SELF GEN                   NaN   2022-01-03             NaT
# 5             UPGRADE                   NaN   2022-02-07      2022-02-07
# 6       AMRM Hand-off                   NaN   2021-12-30      2021-12-30
# 7             UPGRADE                   NaN   2022-01-19      2022-01-19
# ...               ...                   ...          ...             ...
# 8938  Corp Email Lead  Newsletter Soft Lead   2022-03-08             NaT
# 8939  Corp Email Lead  Corp Email Soft Lead   2022-03-08             NaT
# 8940  Corp Email Lead  Newsletter Soft Lead   2022-03-08             NaT
# 8941  Corp Email Lead  Corp Email Soft Lead   2022-03-08             NaT
# 8942  Corp Email Lead  Newsletter Soft Lead   2022-03-08             NaT
#
#      Case Review Completed Enrollment Meeting Set  \
# 1               2022-02-07             2022-02-07
# 4                      NaT                    NaT
# 5                      NaT             2022-02-07
# 6               2022-01-03             2022-01-03
# 7               2022-01-20             2022-02-07
# ...                    ...                    ...
# 8938                   NaT                    NaT
# 8939                   NaT                    NaT
# 8940                   NaT                    NaT
# 8941                   NaT                    NaT
# 8942                   NaT                    NaT
#
#                                          Practice Areas    Stage
# 1                                              Criminal     Deal
# 4     Business Litigation; Criminal; Family; Persona...     Deal
# 5                                              Criminal     Deal
# 6                     Criminal; Family; Personal Injury     Deal
# 7                                           Immigration     Deal
# ...                                                 ...      ...
# 8938                                                NaN  No Deal
# 8939      Appellate Practice General Practice and Trial  No Deal
# 8940                                                NaN  No Deal
# 8941                                                NaN  No Deal
# 8942                                    Personal Injury  No Deal
#
# [8722 rows x 13 columns]

# %%
oppty.df['Lead Source'].unique()
# Out:
# array(['UPGRADE', 'SELF GEN', 'AMRM Hand-off', 'HOTLEAD-Calendly',
#        'HOTLEAD-LMWebForm', 'HOTLEAD-other', 'HOTLEAD-LinkedIn-LGF',
#        'Refer a Colleague', 'MM REFERRAL', 'Corp Email Lead', 'SAVE',
#        'Social Media Engagement', nan, 'HOTLEAD-phone'], dtype=object)

# %%
oppty.df
# Out:
#                                        Opportunity Name Process Tracking For  \
# 1     Michel Rene Huff Bus Lit and PI San Diego Upgr...      Russell Winkler
# 4            Timothy Pollard - Immigration Wait LIst LA       Julie Reynolds
# 5         Rob Laher Early Renewal and Upgrade Crim 2022      Russell Winkler
# 6                           Willis Everett Smith 1.3.22     Jennifer Depazza
# 7     Agnieszka Haupt Immigration Early Renewal and ...      Russell Winkler
# ...                                                 ...                  ...
# 8938     Hayley Wilson - Corp Email Engagement - 3.9.22        Erik Martinez
# 8939       Ryan Malone - Corp Email Engagement - 3.9.22        James Susuico
# 8940      Brennan Moss - Corp Email Engagement - 3.9.22         Jeynifer Kaz
# 8941        Brooke Ray - Corp Email Engagement - 3.9.22      Justin Schwartz
# 8942    Stephen Barnes - Corp Email Engagement - 3.9.22        Brandy Sutton
#
#      CR Set Position CR Completed Position     EM Set Position  \
# 1                NaN                   NaN                 NaN
# 4                NaN                   NaN                 NaN
# 5                NaN                   NaN                 NaN
# 6          BDR-AMRM1    Associate Director  Associate Director
# 7                NaN                   NaN                 NaN
# ...              ...                   ...                 ...
# 8938             NaN                   NaN                 NaN
# 8939             NaN                   NaN                 NaN
# 8940             NaN                   NaN                 NaN
# 8941             NaN                   NaN                 NaN
# 8942             NaN                   NaN                 NaN
#
#           Lead Source      Lead Source Type Created Date Case Review Set  \
# 1             UPGRADE                   NaN   2022-02-07      2022-02-07
# 4            SELF GEN                   NaN   2022-01-03             NaT
# 5             UPGRADE                   NaN   2022-02-07      2022-02-07
# 6       AMRM Hand-off                   NaN   2021-12-30      2021-12-30
# 7             UPGRADE                   NaN   2022-01-19      2022-01-19
# ...               ...                   ...          ...             ...
# 8938  Corp Email Lead  Newsletter Soft Lead   2022-03-08             NaT
# 8939  Corp Email Lead  Corp Email Soft Lead   2022-03-08             NaT
# 8940  Corp Email Lead  Newsletter Soft Lead   2022-03-08             NaT
# 8941  Corp Email Lead  Corp Email Soft Lead   2022-03-08             NaT
# 8942  Corp Email Lead  Newsletter Soft Lead   2022-03-08             NaT
#
#      Case Review Completed Enrollment Meeting Set  \
# 1               2022-02-07             2022-02-07
# 4                      NaT                    NaT
# 5                      NaT             2022-02-07
# 6               2022-01-03             2022-01-03
# 7               2022-01-20             2022-02-07
# ...                    ...                    ...
# 8938                   NaT                    NaT
# 8939                   NaT                    NaT
# 8940                   NaT                    NaT
# 8941                   NaT                    NaT
# 8942                   NaT                    NaT
#
#                                          Practice Areas    Stage
# 1                                              Criminal     Deal
# 4     Business Litigation; Criminal; Family; Persona...     Deal
# 5                                              Criminal     Deal
# 6                     Criminal; Family; Personal Injury     Deal
# 7                                           Immigration     Deal
# ...                                                 ...      ...
# 8938                                                NaN  No Deal
# 8939      Appellate Practice General Practice and Trial  No Deal
# 8940                                                NaN  No Deal
# 8941                                                NaN  No Deal
# 8942                                    Personal Injury  No Deal
#
# [8722 rows x 13 columns]
