# %% [markdown]
# #### Source Files
# 1. Salesforce SaleRep Lead pref - Oppty
#     - https://d300000001vgeeau.my.salesforce.com/00O4y000003xWkb
# 1. Salesforce SaleRep Lead pref - Deal
#     - https://d300000001vgeeau.my.salesforce.com/00O4y000003xWkq

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
tqdm.pandas()

import seaborn as sns

# %% [markdown]
# #### Business Question
# 1. What are the top practice area getting deals?
#     1. Who are the sales rep getting this deals?
#     1. What are their position level?
# 1. What are the type of leads getting deals?

# %%
class dataframe_deals:
    def __init__(self, link):
        self.df = pd.read_csv(link, encoding = 'latin-1')
        self.df.dropna(subset = ['Deal: Deal Name'], inplace = True)
        self.df['Order Date'] = pd.to_datetime(self.df['Order Date'])
        self.practice_area_count()
    
    def practice_area_count(self):
        list = [x for x in self.df.columns if 'Area of Practice' in x]
        self.df['Count of Practice Area'] = self.df.apply(lambda x: 5 - x[list].isna().sum(), axis = 1)
    
    def PA_table(self):
        list = [x for x in self.df.columns if 'Area of Practice' in x]
        list.extend(['Deal: ID', 'Order Date'])
        return self.df[list].melt(id_vars = ['Deal: ID', 'Order Date']).dropna(subset = ['value'])

# %%
deals = dataframe_deals('raw/salesforce salesrep lead pref - deal.csv')

# %% [markdown]
# #### Deals per Practice Area

# %%
test = deals.PA_table()

# %%
df = test.pivot_table(index = ['value'], values = 'variable', aggfunc = 'count').sort_values(by ='variable', ascending = False)

colors = sns.color_palette('pastel')
colors = [colors[0] if df.loc[df.index[x], 'variable'] !=  df.variable.max() else colors[4] for x in range(len(df.index))]
plt.figure(figsize = (15,10))
ax = sns.barplot(data = df, y = df.index, x = 'variable', palette = colors)
for bar in ax.patches:
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    ax.annotate(format(bar.get_width(), ','),
                   (bar.get_width() + 5,
                    bar.get_y() + bar.get_height()), ha='center', va='center',
                   size=10, xytext=(-8, 8),
                   textcoords='offset points')
_ = plt.title("Deals per Practice Area")

# %%
class dataframe_oppty:
    def __init__(self, link):
        self.df = pd.read_csv(link, encoding = 'latin-1')
        
    def auto_run(self):    
        self.data_preparation()
        self.lead_source_filter()
    
    def datetime(self, list):
        for x in list:
            self.df[x] = pd.to_datetime(self.df[x])
    
    def measureit(method):
        '''using a decorator to measure the before and after of dataframe length'''
        def measured(self):
            initial_len = len(self.df)
            result = method(self)
            final_len = len(self.df)
            
            # Printing the result
            print(method.__name__)            
            print(f"Before using the filter: {initial_len}")
            print(f"After using the filter: {final_len}")
            print(f"The dataframe decreased by: {initial_len - final_len}")
            print('======================')
            return result
        return measured            

    @measureit
    def lead_source_filter(self):
        """Removing all types of renewal from the dataset"""
        remove_values = [x for x in self.df['Lead Source'].unique() if 'renewal' in str(x).lower()]
        self.df = self.df[~self.df['Lead Source'].isin(remove_values)]
        
    @measureit
    def data_preparation(self):
        self.df.dropna(subset = ['Process Tracking For'], inplace = True)
        self.datetime(['Created Date', 'Case Review Set', 'Case Review Completed', 'Enrollment Meeting Set'])
        self.filter_list = ['Test Calm Test',
                            'test opp - 3.17.22',
                            'test opp 4.19.22',
                            'Test Calm Test',
                            'Test',
                            'test opp 2.4.22',
                            'test']
        self.df = self.df[~self.df['Opportunity Name'].isin(self.filter_list)]                    
        
    def checker(method):
        def nan_checker(*arg, **kwargs):
            if str(arg) != 'nan':
                return method
            else:
                print('nan type')
                return np.nan
        return nan_checker
    
    def breaking_practice_areas(self):
        def splitter(string_to_list):
            if str(string_to_list) != 'nan':
                return str(string_to_list).split(';')
            else:
                return [np.nan]
        
        self.df['Practice Areas - list'] = self.df.apply(lambda x: splitter(x['Practice Areas']), axis = 1)
        self.df['Practice Areas - Length'] = self.df.apply(lambda x: len(x['Practice Areas - list']) if str(x['Practice Areas - list']) != 'nan' else np.nan, axis = 1)
        
        print(f"=========================")
        print(self.df['Practice Areas - Length'].value_counts())

# %%
oppty = dataframe_oppty('raw/salesforce salesrep lead pref - oppty.csv')
oppty.auto_run()
# Out:
# data_preparation
# Before using the filter: 8948
# After using the filter: 8936
# The dataframe decreased by: 12
# ======================
# lead_source_filter
# Before using the filter: 8936
# After using the filter: 8715
# The dataframe decreased by: 221
# ======================

# %%
oppty.breaking_practice_areas()
# Out:
# =========================
# 1     4661
# 2     1448
# 3     1050
# 4      646
# 5      417
# 6      199
# 7      124
# 8       77
# 9       30
# 10      28
# 11      17
# 12      10
# 14       3
# 13       2
# 17       1
# 22       1
# 15       1
# Name: Practice Areas - Length, dtype: int64

# %%
# pd.DataFrame(oppty.df['Practice Areas - Length'].value_counts()).index.tolist()
len(oppty.df['Practice Areas - Length'].value_counts().index)
# Out:
# 17

# %%
practice_areas = pd.DataFrame(oppty.df['Practice Areas - list'].tolist(), index = oppty.df.index)

# %%
practice_areas.columns = ["Practice Area " + str(x + 1) for x in practice_areas.columns]

# %%
practice_areas.reset_index(drop = False, inplace = True)
practice_areas = practice_areas.melt(id_vars= 'index').dropna()

# %%
practice_areas.set_index('index', inplace = True)

# %%
# get the practice are of deals and who are the process tracking fors
# also check location/state of the deals where they are located
# Check the position level of the rep during the deal

# plan to present this in heatmap format

# %%
df = oppty.df.merge(practice_areas, left_index= True, right_index= True)

# %%
df_deal = df[df['Stage'] == 'Deal']

# %%
sns.heatmap(df_deal.pivot_table(index = 'Lead Source', columns = 'value', values = 'Process Tracking For', aggfunc='count'))
# Out:
# <AxesSubplot:xlabel='value', ylabel='Lead Source'>

# %%
ax = sns.countplot(data = pvot_table.reset_index(drop = False), x = 'Lead Source')
_ = ax.set_xticklabels(labels = pvot_table.index,rotation = 90)

# %%
# Out:
# Lead Source
# SELF GEN                592.0
# HOTLEAD-LMWebForm       186.0
# UPGRADE                 161.0
# HOTLEAD-Calendly         93.0
# AMRM Hand-off            85.0
# HOTLEAD-other             9.0
# HOTLEAD-LinkedIn-LGF      7.0
# Corp Email Lead           5.0
# SAVE                      4.0
# Refer a Colleague         3.0
# MM REFERRAL               1.0
# dtype: float64

# %%
pvot_table.sum(axis = 1)
# Out:
# Lead Source
# AMRM Hand-off            85.0
# Corp Email Lead           5.0
# HOTLEAD-Calendly         93.0
# HOTLEAD-LMWebForm       186.0
# HOTLEAD-LinkedIn-LGF      7.0
# HOTLEAD-other             9.0
# MM REFERRAL               1.0
# Refer a Colleague         3.0
# SAVE                      4.0
# SELF GEN                592.0
# UPGRADE                 161.0
# dtype: float64

# %%
sns.set_color_codes('pastel')
ax = sns.barplot(x = pvot_table.sum(axis = 1).index, y = pvot_table.sum(axis = 1), color = 'b')
_ = ax.set_xticklabels(labels = for_plotting.index, rotation = 90)

# for x in ax.patches:
#     ax.annotate(x.get_height, (x.get_x, x.get_height))
    # print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\LMPH\Documents\sales_rep_lead_preference\Untitled.ipynb Cell 24' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/LMPH/Documents/sales_rep_lead_preference/Untitled.ipynb#ch0000033?line=0'>1</a> sns.set_color_codes('pastel')
#       <a href='vscode-notebook-cell:/c%3A/Users/LMPH/Documents/sales_rep_lead_preference/Untitled.ipynb#ch0000033?line=1'>2</a> ax = sns.barplot(x = pvot_table.sum(axis = 1).index, y = pvot_table.sum(axis = 1), color = 'b')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LMPH/Documents/sales_rep_lead_preference/Untitled.ipynb#ch0000033?line=2'>3</a> _ = ax.set_xticklabels(labels = for_plotting.index, rotation = 90)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axes/_base.py?line=73'>74</a> def wrapper(self, *args, **kwargs):
# ---> <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axes/_base.py?line=74'>75</a>     return get_method(self)(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1795'>1796</a> if fontdict is not None:
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1796'>1797</a>     kwargs.update(fontdict)
# -> <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1797'>1798</a> return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1715'>1716</a> if isinstance(locator, mticker.FixedLocator):
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1716'>1717</a>     # Passing [] as a list of ticklabels is often used as a way to
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1717'>1718</a>     # remove all tick labels, so only error for > 0 ticklabels
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1718'>1719</a>     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1719'>1720</a>         raise ValueError(
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1720'>1721</a>             "The number of FixedLocator locations"
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1721'>1722</a>             f" ({len(locator.locs)}), usually from a call to"
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1722'>1723</a>             " set_ticks, does not match"
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1723'>1724</a>             f" the number of ticklabels ({len(ticklabels)}).")
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1724'>1725</a>     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/matplotlib/axis.py?line=1725'>1726</a>     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11), usually from a call to set_ticks, does not match the number of ticklabels (56).

# %% [markdown]
# #### Insights:
# 1. Highest lead source is still self gen leads
# 1. Check which leads can be breakdowned with email campaign
#     - Possible: HOTLEAD-Calendly

# %%
sns.set_color_codes('pastel')
ax = sns.barplot(x = for_plotting.index, y = for_plotting, color = 'b')
_ = ax.set_xticklabels(labels = for_plotting.index, rotation = 90)

# for x in ax.patches:
#     ax.annotate(x.get_height, (x.get_x, x.get_height))
    # print(x)

# %%
pvot_table = df_deal.pivot_table(index = 'Lead Source', columns = 'value', values = 'Process Tracking For', aggfunc='count')

# %%
pvot_table.sort_values(by = 'SELFGEN', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\LMPH\Documents\sales_rep_lead_preference\Untitled.ipynb Cell 22' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LMPH/Documents/sales_rep_lead_preference/Untitled.ipynb#ch0000026?line=0'>1</a> pvot_table.sort_values(by = 'SELFGEN', ascending = False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6308'>6309</a> elif len(by):
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6309'>6310</a>     # len(by) == 1
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6311'>6312</a>     by = by[0]
# -> <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6312'>6313</a>     k = self._get_label_or_level_values(by, axis=axis)
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6314'>6315</a>     # need to rewrap column in Series to apply key function
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6315'>6316</a>     if key is not None:
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6316'>6317</a>         # error: Incompatible types in assignment (expression has type
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=6317'>6318</a>         # "Series", variable has type "ndarray")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=1837'>1838</a>     values = self.axes[axis].get_level_values(key)._values
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=1838'>1839</a> else:
# -> <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=1839'>1840</a>     raise KeyError(key)
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=1841'>1842</a> # Check for duplicates
#    <a href='file:///c%3A/Users/LMPH/AppData/Roaming/Python/Python39/site-packages/pandas/core/generic.py?line=1842'>1843</a> if values.ndim > 1:
#
# KeyError: 'SELFGEN'

# %%
pvot_table
# Out:
# value                  Bankruptcy   Business Litigation  \
# Lead Source
# AMRM Hand-off                 NaN                   NaN
# Corp Email Lead               NaN                   NaN
# HOTLEAD-Calendly              NaN                   3.0
# HOTLEAD-LMWebForm             1.0                   4.0
# HOTLEAD-LinkedIn-LGF          NaN                   NaN
# HOTLEAD-other                 NaN                   NaN
# MM REFERRAL                   NaN                   NaN
# Refer a Colleague             NaN                   NaN
# SAVE                          NaN                   NaN
# SELF GEN                      1.0                   6.0
# UPGRADE                       NaN                   3.0
#
# value                  Business Transactional   Civil Rights   Class Action  \
# Lead Source
# AMRM Hand-off                             3.0            NaN            NaN
# Corp Email Lead                           1.0            NaN            NaN
# HOTLEAD-Calendly                          6.0            1.0            NaN
# HOTLEAD-LMWebForm                        17.0            1.0            NaN
# HOTLEAD-LinkedIn-LGF                      1.0            NaN            NaN
# HOTLEAD-other                             NaN            NaN            NaN
# MM REFERRAL                               NaN            NaN            NaN
# Refer a Colleague                         NaN            NaN            NaN
# SAVE                                      1.0            NaN            NaN
# SELF GEN                                 46.0            2.0            NaN
# UPGRADE                                  15.0            NaN            2.0
#
# value                  Compensation   Constitutional   Construction  \
# Lead Source
# AMRM Hand-off                   NaN              NaN            NaN
# Corp Email Lead                 NaN              NaN            NaN
# HOTLEAD-Calendly                NaN              NaN            3.0
# HOTLEAD-LMWebForm               NaN              NaN            NaN
# HOTLEAD-LinkedIn-LGF            NaN              NaN            NaN
# HOTLEAD-other                   NaN              NaN            NaN
# MM REFERRAL                     NaN              NaN            NaN
# Refer a Colleague               NaN              NaN            NaN
# SAVE                            NaN              NaN            NaN
# SELF GEN                        1.0              1.0            2.0
# UPGRADE                         NaN              NaN            NaN
#
# value                  Consumer   Criminal  ...  Immigration  Insurance  \
# Lead Source                                 ...
# AMRM Hand-off               NaN        3.0  ...          NaN        NaN
# Corp Email Lead             NaN        1.0  ...          NaN        NaN
# HOTLEAD-Calendly            NaN        3.0  ...          NaN        NaN
# HOTLEAD-LMWebForm           1.0        5.0  ...          NaN        NaN
# HOTLEAD-LinkedIn-LGF        NaN        NaN  ...          1.0        NaN
# HOTLEAD-other               NaN        NaN  ...          NaN        NaN
# MM REFERRAL                 NaN        NaN  ...          NaN        NaN
# Refer a Colleague           NaN        NaN  ...          NaN        NaN
# SAVE                        NaN        NaN  ...          NaN        NaN
# SELF GEN                    2.0       18.0  ...          5.0        2.0
# UPGRADE                     NaN       15.0  ...          1.0        NaN
#
# value                 Intellectual Property  Medical Malpractice  \
# Lead Source
# AMRM Hand-off                           NaN                  NaN
# Corp Email Lead                         NaN                  NaN
# HOTLEAD-Calendly                        NaN                  2.0
# HOTLEAD-LMWebForm                       NaN                  NaN
# HOTLEAD-LinkedIn-LGF                    NaN                  NaN
# HOTLEAD-other                           NaN                  NaN
# MM REFERRAL                             NaN                  NaN
# Refer a Colleague                       NaN                  NaN
# SAVE                                    NaN                  NaN
# SELF GEN                                3.0                  NaN
# UPGRADE                                 NaN                  NaN
#
# value                 Other (See Details)  Personal Injury  Real Estate  Tax  \
# Lead Source
# AMRM Hand-off                         NaN              2.0          4.0  NaN
# Corp Email Lead                       NaN              NaN          NaN  NaN
# HOTLEAD-Calendly                      NaN              2.0          1.0  NaN
# HOTLEAD-LMWebForm                     NaN              1.0          2.0  NaN
# HOTLEAD-LinkedIn-LGF                  NaN              NaN          1.0  NaN
# HOTLEAD-other                         NaN              1.0          NaN  NaN
# MM REFERRAL                           NaN              NaN          NaN  NaN
# Refer a Colleague                     NaN              NaN          NaN  NaN
# SAVE                                  NaN              NaN          NaN  NaN
# SELF GEN                              NaN              6.0         13.0  2.0
# UPGRADE                               1.0              1.0          NaN  NaN
#
# value                 Wills and Trusts  Workers Compensation
# Lead Source
# AMRM Hand-off                      2.0                   NaN
# Corp Email Lead                    NaN                   NaN
# HOTLEAD-Calendly                   NaN                   NaN
# HOTLEAD-LMWebForm                  1.0                   NaN
# HOTLEAD-LinkedIn-LGF               1.0                   NaN
# HOTLEAD-other                      NaN                   NaN
# MM REFERRAL                        NaN                   NaN
# Refer a Colleague                  NaN                   NaN
# SAVE                               NaN                   NaN
# SELF GEN                          11.0                   1.0
# UPGRADE                            3.0                   NaN
#
# [11 rows x 56 columns]
